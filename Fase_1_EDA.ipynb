# %% [markdown]
# ## <span style="color:#00bf63">**Fase 1**</span>
# ___
# ### <span >**1. Análisis Exploratorio de Datos (EDA) 🔎**</span>
# - **Importamos librerías 📚 y extendemos la visualización 💻**

# %%
import pandas as pd

# -----------------------------------------------------------------------

pd.set_option('display.max_columns', None) 
pd.set_option('display.max_colwidth', None)

# %%
# Función para leer Dataset.
def leer_dataset(ruta1, ruta2, ruta3):
    df1 = pd.read_csv(ruta1)
    df2 = pd.read_csv(ruta2)
    df3 = pd.read_csv(ruta3)
    return df1, df2, df3

# %%
# LLamamos a la función leer el Dataset.
ruta_clientes = "clientes.csv"
ruta_productos = "productos.csv"
ruta_ventas = "ventas.csv"

df_clientes, df_productos, df_ventas = leer_dataset(ruta_clientes,ruta_productos,ruta_ventas)

# %%
df_clientes.head(2)
# Out:
#   id_cliente nombre  apellido           ciudad
# 0      C0001  Julia     López  Granada, España
# 1      C0002  Elena  Martínez  Granada, España

# %%
df_clientes.shape
# Out:
# (300, 4)

# %%
df_productos.head(4)
# Out:
#   id_producto   precio          categoria  \
# 0       P0001  58.91 €           Clothing
# 1       P0002  15.67 €        Electronics
# 2       P0003  50.58 €  Sports & Outdoors
# 3       P0004  72.88 €  Sports & Outdoors
#
#                                           descripcion
# 0  6GJFfPug1voQYH3zfXItpbjwRA7VVT64DGtG8VnRXaJJZ0SYJa
# 1  Ai3c6EdaRU5C0WuWl718dSYHakqGLiMJmpbVgn7iq6syGN3UJP
# 2  yMidjq8PGxKEf6YFWfUKJN1sDhyIs2xareF0uaA4ngzUgmrDKc
# 3  E8LBdxZItLULWZUyKPwzkjZJHD2GOSuqR7Od4DX5624ex1t5lN

# %%
df_productos.shape
# Out:
# (600, 4)

# %%
df_ventas.head(2)
# Out:
#   id_venta id_producto  cantidad       fecha id_cliente
# 0  V004849       P0173         4  2024-05-16      C0203
# 1  V003181       P0165         9  2022-09-12      C0004

# %%
df_ventas.shape
# Out:
# (80000, 5)

# %% [markdown]
# - **Exploramos los DataFrames**

# %%
def exploracion_dataframe(dataframe):
    print(f"Duplicados en el conjunto de datos: {dataframe.duplicated().sum()}")
    
    
    print("\n ..................... \n")


    # Generamos un DataFrame para los valores nulos
    print("Nulos en el conjunto de datos:")
    df_nulos_num = pd.DataFrame(dataframe.isnull().sum() / dataframe.shape[0] * 100, columns = ["%_nulos"])
    display(df_nulos_num[df_nulos_num["%_nulos"] > 0])
    

    # Nulos en columnas categóricas
    print("Nulos en columnas categóricas:")
    df_nulos_cat = pd.DataFrame(dataframe.select_dtypes(include="object").isnull().sum() / dataframe.shape[0] * 100, columns=["%_nulos"])
    display(df_nulos_cat[df_nulos_cat["%_nulos"] > 0])
    
    
    print("\n ..................... \n")
    

    print(f"Tipos de columnas:")
    display(pd.DataFrame(dataframe.dtypes, columns = ["tipo_dato"]))
    
    for col in dataframe.columns:
        print(f"Valores únicos de la columna {col.upper()}:")
        display(pd.DataFrame(dataframe[col].value_counts()).head(12))

# %%
exploracion_dataframe(df_clientes)
# Out:
# Duplicados en el conjunto de datos: 0
#
#  .....................
#
# Nulos en el conjunto de datos:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
# Nulos en columnas categóricas:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  .....................
#
# Tipos de columnas:
#            tipo_dato
# id_cliente    object
# nombre        object
# apellido      object
# ciudad        object
# Valores únicos de la columna ID_CLIENTE:
#             count
# id_cliente
# C0300           1
# C0001           1
# C0002           1
# C0003           1
# C0004           1
# C0005           1
# C0006           1
# C0007           1
# C0008           1
# C0009           1
# C0010           1
# C0011           1
# Valores únicos de la columna NOMBRE:
#         count
# nombre
# María      42
# Ana        37
# Marta      34
# Sofía      33
# Elena      32
# Lucía      28
# Laura      26
# Carmen     25
# Clara      23
# Julia      20
# Valores únicos de la columna APELLIDO:
#            count
# ...

# %%
exploracion_dataframe(df_ventas)
# Out:
# Duplicados en el conjunto de datos: 80
#
#  .....................
#
# Nulos en el conjunto de datos:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
# Nulos en columnas categóricas:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  .....................
#
# Tipos de columnas:
#             tipo_dato
# id_venta       object
# id_producto    object
# cantidad        int64
# fecha          object
# id_cliente     object
# Valores únicos de la columna ID_VENTA:
#           count
# id_venta
# V005860      23
# V002430      23
# V004944      23
# V000395      22
# V007213      22
# V003054      21
# V000084      21
# V006795      21
# V003006      21
# V005828      21
# V005281      21
# V005125      21
# Valores únicos de la columna ID_PRODUCTO:
#              count
# id_producto
# P0057          209
# P0269          209
# P0193          202
# P0026          199
# P0410          197
# P0068          197
# P0456          196
# P0021          196
# P0044          195
# ...

# %%
exploracion_dataframe(df_productos)
# Out:
# Duplicados en el conjunto de datos: 0
#
#  .....................
#
# Nulos en el conjunto de datos:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
# Nulos en columnas categóricas:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  .....................
#
# Tipos de columnas:
#             tipo_dato
# id_producto    object
# precio         object
# categoria      object
# descripcion    object
# Valores únicos de la columna ID_PRODUCTO:
#              count
# id_producto
# P0600            1
# P0001            1
# P0002            1
# P0003            1
# P0004            1
# P0005            1
# P0006            1
# P0007            1
# P0008            1
# P0009            1
# P0010            1
# P0011            1
# Valores únicos de la columna PRECIO:
#          count
# precio
# 58.91 €      3
# 29.29 €      2
# 83.70 €      2
# 34.67 €      2
# 85.45 €      2
# 72.61 €      2
# 43.80 €      2
# 94.87 €      2
# 36.65 €      2
# 19.83 €      2
# 69.00 €      2
# ...

# %% [markdown]
# - **Cambios df_clientes**

# %%
# Separamos la columna 'ciudad' en dos columnas: 'ciudad' y 'pais'
df_clientes[['ciudad', 'pais']] = df_clientes['ciudad'].str.split(', ', expand=True)

# %% [markdown]
# - **Comprobaciones df_clientes✅**

# %%
df_clientes.head(10)
# Out:
#   id_cliente  nombre   apellido    ciudad      pais
# 0      C0001   Julia      López   Granada    España
# 1      C0002   Elena   Martínez   Granada    España
# 2      C0003   Laura    Sánchez      Lyon   Francia
# 3      C0004   Marta      López  Valencia    España
# 4      C0005     Ana   Martínez     París   Francia
# 5      C0006   Elena      López     Braga  Portugal
# 6      C0007   Laura   González  Zaragoza    España
# 7      C0008   Marta      López   Sevilla    España
# 8      C0009     Ana  Hernández   Sevilla    España
# 9      C0010  Carmen      López   Granada    España

# %% [markdown]
# - **Cambios df_ventas**

# %%
# Cambiamos de tipo de dato de la columna "fecha" de object a fecha.
df_ventas['fecha'] = pd.to_datetime(df_ventas['fecha'], format='%Y-%m-%d')

# %% [markdown]
# - **Comprobaciones df_ventas✅**

# %%
df_ventas.head(10)
# Out:
#   id_venta id_producto  cantidad      fecha id_cliente
# 0  V004849       P0173         4 2024-05-16      C0203
# 1  V003181       P0165         9 2022-09-12      C0004
# 2  V000311       P0194        10 2020-12-02      C0156
# 3  V002787       P0167         1 2023-07-22      C0058
# 4  V002726       P0417        10 2022-04-10      C0099
# 5  V003374       P0484         3 2022-11-11      C0039
# 6  V007378       P0394         4 2024-03-15      C0150
# 7  V005799       P0024         4 2023-11-01      C0244
# 8  V001810       P0449         6 2022-12-01      C0032
# 9  V005219       P0269        10 2021-09-04      C0229

# %%
df_ventas["fecha"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# El resultado dtype('<M8[ns]') indica que los valores en la columna "fecha" son de tipo datetime64[ns], lo cual significa que son fechas y horas representadas a nivel de nanosegundos.

# %% [markdown]
# - **Cambios df_productos**

# %%
# Reemplazamos el símbolo del euro y cambiamos de tipo de dato de la columna "precio" de object a float.

def quitar_metacaracteres(dataframe, columna):
    # Función para reemplazar el símbolo del euro y cualquier espacio adicional por una cadena vacía.
    dataframe[columna] = dataframe[columna].str.replace('€', '', regex=True).str.strip()
    return dataframe

def obj_float(dataframe, columna):
    # Función para convertir el tipo de dato de obj a float.
    dataframe[columna] = dataframe[columna].astype(float)
    return dataframe

# %%
# Ejecutamos la primera función. 
df_productos = quitar_metacaracteres(df_productos, "precio")

# %%
# Ejecutamos la segunda función:
df_productos = obj_float(df_productos, "precio")

# %% [markdown]
# - **Comprobaciones df_productos✅**

# %%
df_productos.head(10)
# Out:
#   id_producto  precio          categoria  \
# 0       P0001   58.91           Clothing
# 1       P0002   15.67        Electronics
# 2       P0003   50.58  Sports & Outdoors
# 3       P0004   72.88  Sports & Outdoors
# 4       P0005   70.23              Books
# 5       P0006   38.15     Home & Kitchen
# 6       P0007   29.46              Books
# 7       P0008   84.19           Clothing
# 8       P0009   22.99              Books
# 9       P0010   32.40              Books
#
#                                           descripcion
# 0  6GJFfPug1voQYH3zfXItpbjwRA7VVT64DGtG8VnRXaJJZ0SYJa
# 1  Ai3c6EdaRU5C0WuWl718dSYHakqGLiMJmpbVgn7iq6syGN3UJP
# 2  yMidjq8PGxKEf6YFWfUKJN1sDhyIs2xareF0uaA4ngzUgmrDKc
# 3  E8LBdxZItLULWZUyKPwzkjZJHD2GOSuqR7Od4DX5624ex1t5lN
# 4  zQLYUssRkFNu2GcCd8xBPrc5xiJH5DGQ66A0X4TFU0cHeazM6o
# 5  BWTEBnPofLlnlzXIs7YGgeCuEdkHaoAptjWkFF3K6fWFreSdkj
# 6  wRY7bHnZGHvTI0Wohm402P4HiSvNdT6rlMn3yPP5t2eYEUfYXD
# 7  BwMy4M0Yd7xVeG9VBApK2M5w0jZNBBUxdDBmNI7wMl05DFzgyF
# ...

# %%
df_productos["precio"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### <span >**2. Guardamos los csv 🗂️**</span>

# %%
# Guardamos los DataFrames transformados en archivos CSV.
df_clientes.to_csv("clientes2.csv", index=False)
df_ventas.to_csv("ventas2.csv", index=False)
df_productos.to_csv("productos2.csv", index=False)
